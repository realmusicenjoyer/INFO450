# %% [markdown]
# <a href="https://colab.research.google.com/github/realmusicenjoyer/INFO450/blob/main/Lesson5/Lesson5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url="https://raw.githubusercontent.com/realmusicenjoyer/INFO450/refs/heads/main/Lesson5/soccer.json"
response=requests.get(url)
response.status_code
response.raise_for_status()
data=response.json()
data
data.keys()
data['matches'][103]
# Out:
# {'round': 'Final',
#  'date': '2026-07-19',
#  'time': '15:00 UTC-4',
#  'team1': 'Spain',
#  'team2': 'Argentina',
#  'score': {'et': [1, 0], 'ft': [0, 0], 'ht': [0, 0]},
#  'goals1': [{'name': 'Ferran TORRES', 'minute': '106'}],
#  'goals2': [],
#  'ground': 'New York/New Jersey Stadium, New Jersey',
#  'attendance': 80663,
#  'lineup': [{'starter': [{'name': 'Unai SIMON'},
#     {'name': 'Pedro PORRO'},
#     {'name': 'Aymeric LAPORTE'},
#     {'name': 'Pau CUBARSI'},
#     {'name': 'Marc CUCURELLA'},
#     {'name': 'Fabian RUIZ'},
#     {'name': 'Alex BAENA'},
#     {'name': 'RODRI', 'captain': True},
#     {'name': 'Dani OLMO'},
#     {'name': 'Lamine YAMAL'},
#     {'name': 'Mikel OYARZABAL'}],
#    'bench': [{'name': 'Eric GARCIA'},
#     {'name': 'PEDRI'},
#     {'name': 'Nico WILLIAMS'},
#     {'name': 'Martin ZUBIMENDI'},
#     {'name': 'Mikel MERINO'},
#     {'name': 'Ferran TORRES'}],
#    'subs': [{'on': 'PEDRI', 'off': 'Fabian RUIZ', 'minute': '62'},
# ...
